# %%
#data cleaning

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

data=pd.read_csv('athlete_events.csv')
j=pd.read_csv('athlete_events.csv')

data_NOC_unique=data['NOC'].unique()

data_countries=pd.DataFrame(data['Team'])

data['NOC']=data['NOC'].replace(['RUS','URS'],'EUN')

data['NOC']=data['NOC'].replace('ANZ','AUS')
data['NOC']=data['NOC'].replace('NFL','CAN')
data['NOC']=data['NOC'].replace('HKG','CHN')
data['NOC']=data['NOC'].replace('UAR','SYR')
data['NOC']=data['NOC'].replace(['SCG','YUG'],'SRB')
data['NOC']=data['NOC'].replace(['MAS','NBO'],'MAL')
data['NOC']=data['NOC'].replace(['BOH','TCH'],'CZE')
data['NOC']=data['NOC'].replace('CRT','GRE')
data['NOC']=data['NOC'].replace(['FRG','GDR','SAA'],'GER')
data['NOC']=data['NOC'].replace('WIF','TTO')
data['NOC']=data['NOC'].replace('VNM','VIE')
data['NOC']=data['NOC'].replace(['YAR','YMD'],'YEM')
data['NOC']=data['NOC'].replace('SIN','SGP')
data['NOC']=data['NOC'].replace('RHO','ZIM')
data['NOC']=data['NOC'].replace(['ROT','TUV'],'UNK')




data=data.drop(columns="Games")

#replacing Male with 1 and female 0

data['Sex'] = data['Sex'].replace('M',1)
data['Sex'] = data['Sex'].replace('F',0)

#replacing summer with 1 and winter with 0

data['Season']=data['Season'].replace('Summer',1)
data['Season']=data['Season'].replace('Winter',0)

#replacing gold with 1, silver with 2 , bronze with 3 , NaN with 0
data['Medal']=data['Medal'].replace('Gold',1)    
data['Medal']=data['Medal'].replace('Silver',2)
data['Medal']=data['Medal'].replace('Bronze',3)

data['Medal'] = data.Medal.fillna(0).astype(int)
data['Age']=data.Age.fillna(24).astype(float)
data['Height']=data.Height.fillna(150).astype(int)
data['Weight']=data.Weight.fillna(70).astype(int)
data.describe()
data=data.drop(columns=['City','Event','Team'])

data['Season']=data['Season'].astype('category')
data['Sex']=data['Sex'].astype('category')
data['Year']=data['Year'].astype('category')
data['Sport']=data['Sport'].astype('category')
data['Sex']=data['Sex'].astype('category')
data_NOC=pd.read_csv('noc_regions.csv')
data_NOC_unique=data['NOC'].unique()

data['Height'][(data['Height']==0)&(data['Weight']==0)&(data['Sex']==1)]=179
data['Height'][(data['Height']==0)&(data['Weight']==0)&(data['Sex']==0)]=168
data['Height'][(data['Weight']>=83)&(data['Height']==0)&(data['Sex']==1)]=185
data['Height'][(data['Weight']>=65)&(data['Height']==0)&(data['Sex']==0)]=173
data['Height'][(data['Weight']<=67)&(data['Height']==0)&(data['Sex']==1)]=172
data['Height'][(data['Weight']<=54)&(data['Height']==0)&(data['Sex']==0)]=162
data['Height'][(data['Weight']<83)&(data['Weight']>67)&(data['Height']==0)&(data['Sex']==1)]=179
data['Height'][(data['Weight']<65)&(data['Weight']>54)&(data['Height']==0)&(data['Sex']==0)]=168


data['Weight'][(data['Height']==0)&(data['Weight']==0)&(data['Sex']==1)]=74
data['Weight'][(data['Height']==0)&(data['Weight']==0)&(data['Sex']==0)]=59
data['Weight'][(data['Height']>=185)&(data['Weight']==0)&(data['Sex']==1)]=83
data['Weight'][(data['Height']>=173)&(data['Weight']==0)&(data['Sex']==0)]=65
data['Weight'][(data['Height']<=172)&(data['Weight']==0)&(data['Sex']==1)]=67
data['Weight'][(data['Height']<=162)&(data['Weight']==0)&(data['Sex']==0)]=54
data['Weight'][(data['Height']<185)&(data['Height']>172)&(data['Weight']==0)&(data['Sex']==1)]=74
data['Weight'][(data['Height']<173)&(data['Height']>162)&(data['Weight']==0)&(data['Sex']==0)]=59

data.info()
# Out:
# C:\Users\Jordon\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Jordon\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Jordon\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Jordon\Anaconda3\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# ...

# %%
#countplot for Sports
sb.catplot(y = "Sport", data = data, kind = "count", height = 10)

# %%
# Extract only the numeric data variables
numeric_data = pd.DataFrame(data[["Age", "Height", "Weight"]])

# Summary Statistics for all Variables
numeric_data.describe().round(2)
# Out:
#              Age     Height     Weight
# count  271116.00  271116.00  271116.00
# mean       25.50     169.72      70.54
# std         6.29      14.03      12.58
# min        10.00     127.00      25.00
# 25%        22.00     157.00      63.00
# 50%        24.00     171.00      70.00
# 75%        28.00     180.00      75.00
# max        97.00     226.00     214.00

# %%
# Draw the distributions (Boxplot, KDE and Histogram, Violinplot) of all numeric variables
f, axes = plt.subplots(3, 3, figsize=(18, 10))
colors = ["r", "g", "b"]
age_height_weight = ['Age','Height','Weight']

for i in range(3):
    sb.boxplot(data[age_height_weight[i]], orient = "h", color = colors[i], ax = axes[i,0])
    sb.distplot(data[age_height_weight[i]], color = colors[i], ax = axes[i,1])
    sb.violinplot(data[age_height_weight[i]], color = colors[i], ax = axes[i,2])
# Out:
# C:\Users\Jordon\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Correlation Matrix
age_height_weight_medal = ['Age','Height','Weight','Medal']
print(data[age_height_weight_medal].corr())
correlation_data = pd.DataFrame(data[["Age", "Height", "Weight","Medal"]])
# Heatmap of the Correlation Matrix
f, axes = plt.subplots(1, 1, figsize=(5, 5))
sb.heatmap(correlation_data.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
#              Age    Height    Weight     Medal
# Age     1.000000 -0.023303  0.158756  0.022929
# Height -0.023303  1.000000  0.533879  0.045579
# Weight  0.158756  0.533879  1.000000  0.068022
# Medal   0.022929  0.045579  0.068022  1.000000

# %%
#Pairplot of Numerical Data Age, Height and Weight
sb.pairplot(data = data[age_height_weight])

# %%
# Compute the Average Height across every pair of Sport & Medal
total_means = data.groupby(['Sport', 'Medal']).mean().loc[:, 'Height']

# Heatmap of Average Height across every pair of Sport & Medal
f, axes = plt.subplots(1, 1, figsize=(10, 25))
sb.heatmap(total_means.unstack(), linewidths = 1,
           annot = True, fmt = ".0f", annot_kws = {"size": 18}, cmap = "BuGn")

# %%
# Compute the Average Weight across every pair of Sport & Medal
total_means = data.groupby(['Sport', 'Medal']).mean().loc[:, 'Weight']

# Heatmap of Average Weight across every pair of Sport & Medal
f, axes = plt.subplots(1, 1, figsize=(10, 25))
sb.heatmap(total_means.unstack(), linewidths = 1,
           annot = True, fmt = ".0f", annot_kws = {"size": 18}, cmap = "BuGn")

# %%
# Compute the Average Age across every pair of Sport & Medal
total_means = data.groupby(['Sport', 'Medal']).mean().loc[:, 'Age']

# Heatmap of Average Age across every pair of Sport & Medal
f, axes = plt.subplots(1, 1, figsize=(10, 25))
sb.heatmap(total_means.unstack(), linewidths = 1,
           annot = True, fmt = ".0f", annot_kws = {"size": 18}, cmap = "BuGn")

# %%
#Boxplot of Sport vs Height
plt.figure(figsize=(16, 15))
sb.boxplot(x='Height',y='Sport',data=data, palette='rainbow')

# %%
#Boxplot of Sport vs Weight
plt.figure(figsize=(16, 15))
sb.boxplot(x='Weight',y='Sport',data=data, palette='rainbow')

# %%
#Boxplot of Sport vs Age
plt.figure(figsize=(16, 15))
sb.boxplot(x='Age',y='Sport',data=data, palette='rainbow')

# %%
#Boxplot of Height vs Medal
plt.figure(figsize=(8, 8))
sb.boxplot(x='Medal',y='Height',data=data, palette='rainbow')

# %%
#Boxplot of Weight vs Medal
plt.figure(figsize=(8, 8))
sb.boxplot(x='Medal',y='Weight',data=data, palette='rainbow')

# %%
#Boxplot of Country vs Height
plt.figure(figsize=(16, 40))
sb.boxplot(x='Height',y='NOC',data=data, palette='rainbow')

# %%
#Boxplot of Country vs Weight
plt.figure(figsize=(16, 40))
sb.boxplot(x='Weight',y='NOC',data=data, palette='rainbow')

# %% [markdown]
# Below we will be breaking up each sport into their Male and Female athletes.
# Plotting boxplots based on Male Height/Male Weight/Female Height/Female Weight against the medals for every sport to see the classification.

# %%
#this function is to get the 4 datasets so that we do not need to repeat this code for every single sport
def get_sport_dataset(i):
    dataset = data[(data.Sport == i)]
    dataset_male = dataset[(dataset.Sex == 1)]
    dataset_male_height = pd.DataFrame(dataset_male['Height'])
    dataset_male_weight = pd.DataFrame(dataset_male['Weight'])
    dataset_male_medal = pd.DataFrame(dataset_male['Medal'])
    male_weight_medalDF = pd.concat([dataset_male_weight, dataset_male_medal], axis = 1, join_axes = [dataset_male_weight.index])
    male_height_medalDF = pd.concat([dataset_male_height, dataset_male_medal], axis = 1, join_axes = [dataset_male_height.index])
    
    dataset_female = dataset[(dataset.Sex == 0)]
    dataset_female_height = pd.DataFrame(dataset_female['Height'])
    dataset_female_weight = pd.DataFrame(dataset_female['Weight'])
    dataset_female_medal = pd.DataFrame(dataset_female['Medal'])
    female_weight_medalDF = pd.concat([dataset_female_weight, dataset_female_medal], axis = 1, join_axes = [dataset_female_weight.index])
    female_height_medalDF = pd.concat([dataset_female_height, dataset_female_medal], axis = 1, join_axes = [dataset_female_height.index])
   
    return male_weight_medalDF,male_height_medalDF,female_weight_medalDF,female_height_medalDF

# %%
#getting individual datasets for each sport. 
male_aeronautics_weight,male_aeronautics_height,female_aeronautics_weight,female_aeronautics_height= get_sport_dataset('Aeronautics')

male_askiing_weight,male_askiing_height,female_askiing_weight,female_askiing_height= get_sport_dataset('Alpine Skiing')

male_alpinism_weight,male_alpinism_height,female_alpinism_weight,female_alpinism_height= get_sport_dataset('Alpinism')

male_archery_weight,male_archery_height,female_archery_weight,female_archery_height= get_sport_dataset('Archery')

male_artc_weight,male_artc_height,female_artc_weight,female_artc_height= get_sport_dataset('Art Competitions')

male_athletics_weight,male_athletics_height,female_athletics_weight,female_athletics_height= get_sport_dataset('Athletics')

male_badminton_weight,male_badminton_height,female_badminton_weight,female_badminton_height= get_sport_dataset('Badminton')

male_baseball_weight,male_baseball_height,female_baseball_weight,female_baseball_height= get_sport_dataset('Baseball')

male_basketball_weight,male_basketball_height,female_basketball_weight,female_basketball_height= get_sport_dataset('Basketball')

male_basque_weight,male_basque_height,female_basque_weight,female_basque_height= get_sport_dataset('Basque Pelota')

male_beachvolley_weight,male_beachvolley_height,female_beachvolley_weight,female_beachvolley_height= get_sport_dataset('Beach Volleyball')

male_biathlon_weight,male_biathlon_height,female_biathlon_weight,female_biathlon_height= get_sport_dataset( 'Biathlon')

male_bobsleigh_weight,male_bobsleigh_height,female_bobsleigh_weight,female_bobsleigh_height= get_sport_dataset('Bobsleigh')

male_boxing_weight,male_boxing_height,female_boxing_weight,female_boxing_height= get_sport_dataset('Boxing')

male_canoe_weight,male_canoe_height,female_canoe_weight,female_canoe_height= get_sport_dataset('Canoeing')

male_cricket_weight,male_cricket_height,female_cricket_weight,female_cricket_height= get_sport_dataset('Cricket')

male_croquet_weight,male_croquet_height,female_croquet_weight,female_croquet_height= get_sport_dataset('Croquet')

male_ccskiing_weight,male_ccskiing_height,female_ccskiing_weight,female_ccskiing_height= get_sport_dataset('Cross Country Skiing')

male_curling_weight,male_curling_height,female_curling_weight,female_curling_height= get_sport_dataset('Curling')

male_cycling_weight,male_cycling_height,female_cycling_weight,female_cycling_height= get_sport_dataset('Cycling')

male_diving_weight,male_diving_height,female_diving_weight,female_diving_height= get_sport_dataset('Diving')

male_equestrianism_weight,male_equestrianism_height,female_equestrianism_weight,female_equestrianism_height= get_sport_dataset('Equestrianism')

male_fencing_weight,male_fencing_height,female_fencing_weight,female_fencing_height= get_sport_dataset('Fencing')

male_figureskating_weight,male_figureskating_height,female_figureskating_weight,female_figureskating_height= get_sport_dataset('Figure Skating')

male_football_weight,male_football_height,female_football_weight,female_football_height= get_sport_dataset('Football')

male_fskiing_weight,male_fskiing_height,female_fskiing_weight,female_fskiing_height= get_sport_dataset('Freestyle Skiing')

male_golf_weight,male_golf_height,female_golf_weight,female_golf_height= get_sport_dataset('Golf')

male_gymnastics_weight,male_gymnastics_height,female_gymnastics_weight,female_gymnastics_height= get_sport_dataset('Gymnastics')

male_handball_weight,male_handball_height,female_handball_weight,female_handball_height= get_sport_dataset('Handball')

male_hockey_weight,male_hockey_height,female_hockey_weight,female_hockey_height= get_sport_dataset('Hockey')

male_icehockey_weight,male_icehockey_height,female_icehockey_weight,female_icehockey_height= get_sport_dataset('Ice Hockey')

male_jeudepaume_weight,male_jeudepaume_height,female_jeudepaume_weight,female_jeudepaume_height= get_sport_dataset('Jeu De Paume')

male_judo_weight,male_judo_height,female_judo_weight,female_judo_height= get_sport_dataset('Judo')

# %%
male_lacrosse_weight,male_lacrosse_height,female_lacrosse_weight,female_lacrosse_height= get_sport_dataset('Lacrosse')

male_luge_weight,male_luge_height,female_luge_weight,female_luge_height= get_sport_dataset('Luge')

male_skipatrol_weight,male_skipatrol_height,female_skipatrol_weight,female_skipatrol_height= get_sport_dataset('Military Ski Patrol')

male_pentathlon_weight,male_pentathlon_height,female_pentathlon_weight,female_pentathlon_height= get_sport_dataset('Modern Pentathlon')

male_motorboat_weight,male_motorboat_height,female_motorboat_weight,female_motorboat_height= get_sport_dataset('Motorboating')

male_nordic_weight,male_nordic_height,female_nordic_weight,female_nordic_height= get_sport_dataset('Nordic Combined')

male_polo_weight,male_polo_height,female_polo_weight,female_polo_height= get_sport_dataset('Polo')

male_racquets_weight,male_racquets_height,female_racquets_weight,female_racquets_height= get_sport_dataset('Racquets')

male_rgymnastics_weight,male_rgymnastics_height,female_rgymnastics_weight,female_rgymnastics_height= get_sport_dataset('Rhythmic Gymnastics')

male_roque_weight,male_roque_height,female_roque_weight,female_roque_height= get_sport_dataset('Roque')

male_rowing_weight,male_rowing_height,female_rowing_weight,female_rowing_height= get_sport_dataset('Rowing')

male_rugby_weight,male_rugby_height,female_rugby_weight,female_rugby_height= get_sport_dataset('Rugby')

male_rugby7_weight,male_rugby7_height,female_rugby7_weight,female_rugby7_height= get_sport_dataset('Rugby Sevens')

male_sailing_weight,male_sailing_height,female_sailing_weight,female_sailing_height= get_sport_dataset('Sailing')

male_shooting_weight,male_shooting_height,female_shooting_weight,female_shooting_height= get_sport_dataset('Shooting')

male_shortskating_weight,male_shortskating_height,female_shortskating_weight,female_shortskating_height= get_sport_dataset('Short Track Speed Skating')

male_skeleton_weight,male_skeleton_height,female_skeleton_weight,female_skeleton_height= get_sport_dataset('Skeleton')

male_skijump_weight,male_skijump_height,female_skijump_weight,female_skijump_height= get_sport_dataset('Ski Jumping')

male_snowboarding_weight,male_snowboarding_height,female_snowboarding_weight,female_snowboarding_height= get_sport_dataset('Snowboarding')

male_softball_weight,male_softball_height,female_softball_weight,female_softball_height= get_sport_dataset('Softball')

male_speedskating_weight,male_speedskating_height,female_speedskating_weight,female_speedskating_height= get_sport_dataset('Speed Skating')

male_swimming_weight,male_swimming_height,female_swimming_weight,female_swimming_height= get_sport_dataset('Swimming')

male_syncswimming_weight,male_syncswimming_height,female_syncswimming_weight,female_syncswimming_height= get_sport_dataset('Synchronized Swimming')

male_tabletennis_weight,male_tabletennis_height,female_tabletennis_weight,female_tabletennis_height= get_sport_dataset('Table Tennis')

male_taekwondo_weight,male_taekwondo_height,female_taekwondo_weight,female_taekwondo_height= get_sport_dataset('Taekwondo')

male_tennis_weight,male_tennis_height,female_tennis_weight,female_tennis_height= get_sport_dataset('Tennis')

male_trampolining_weight,male_trampolining_height,female_trampolining_weight,female_trampolining_height= get_sport_dataset('Trampolining')

male_triathlon_weight,male_triathlon_height,female_triathlon_weight,female_triathlon_height= get_sport_dataset('Triathlon')

male_tugofwar_weight,male_tugofwar_height,female_tugofwar_weight,female_tugofwar_height= get_sport_dataset('Tug-Of-War')

male_volleyball_weight,male_volleyball_height,female_volleyball_weight,female_volleyball_height= get_sport_dataset('Volleyball')

male_waterpolo_weight,male_waterpolo_height,female_waterpolo_weight,female_waterpolo_height= get_sport_dataset('Water Polo')

male_weightlifting_weight,male_weightlifting_height,female_weightlifting_weight,female_weightlifting_height= get_sport_dataset('Weightlifting')

male_wrestling_weight,male_wrestling_height,female_wrestling_weight,female_wrestling_height= get_sport_dataset('Wrestling')

# %%
#plotting them boxplots. 4 for each sport(male-female height-weight )
f, axes = plt.subplots(99, 2, figsize=(22, 775))



sb.boxplot(x = "Weight", y = "Medal",data = male_askiing_weight, orient = "h",ax=axes[0,0]).set_title("Male Alpine Skiiers")
sb.boxplot(x = "Height", y = "Medal", data = male_askiing_height, orient = "h",ax=axes[0,1]).set_title("Male Alpine Skiiers")

sb.boxplot(x = "Weight", y = "Medal",data = female_askiing_weight, orient = "h",ax=axes[1,0]).set_title("Female Alpine Skiiers")
sb.boxplot(x = "Height", y = "Medal", data = female_askiing_height, orient = "h",ax=axes[1,1]).set_title("Female Alpine Skiiers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_archery_weight, orient = "h",ax=axes[2,0]).set_title("Male Archers")
sb.boxplot(x = "Height", y = "Medal", data = male_archery_height, orient = "h",ax=axes[2,1]).set_title("Male Archers")

sb.boxplot(x = "Weight", y = "Medal",data = female_archery_weight, orient = "h",ax=axes[3,0]).set_title("Female Archers")
sb.boxplot(x = "Height", y = "Medal", data = female_archery_height, orient = "h",ax=axes[3,1]).set_title("Female Archers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_athletics_weight, orient = "h",ax=axes[4,0]).set_title("Male Athletics Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_athletics_height, orient = "h",ax=axes[4,1]).set_title("Male Athletics Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_athletics_weight, orient = "h",ax=axes[5,0]).set_title("Female Athletics Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_athletics_height, orient = "h",ax=axes[5,1]).set_title("Female Athletics Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_badminton_weight, orient = "h",ax=axes[6,0]).set_title("Male Badminton Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_badminton_height, orient = "h",ax=axes[6,1]).set_title("Male Badminton Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_badminton_weight, orient = "h",ax=axes[7,0]).set_title("Female Badminton Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_badminton_height, orient = "h",ax=axes[7,1]).set_title("Female Badminton Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_baseball_weight, orient = "h",ax=axes[8,0]).set_title("Male Baseball Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_baseball_height, orient = "h",ax=axes[8,1]).set_title("Male Baseball Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_basketball_weight, orient = "h",ax=axes[9,0]).set_title("Male Basketball Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_basketball_height, orient = "h",ax=axes[9,1]).set_title("Male Basketball Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_basketball_weight, orient = "h",ax=axes[10,0]).set_title("Female Basketball Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_basketball_height, orient = "h",ax=axes[10,1]).set_title("Female Basketball Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_beachvolley_weight, orient = "h",ax=axes[11,0]).set_title("Male Beach Volleyball")
sb.boxplot(x = "Height", y = "Medal", data = male_beachvolley_height, orient = "h",ax=axes[11,1]).set_title("Male Beach Volleyball")

sb.boxplot(x = "Weight", y = "Medal",data = female_beachvolley_weight, orient = "h",ax=axes[12,0]).set_title("Female Beach Volleyball")
sb.boxplot(x = "Height", y = "Medal", data = female_beachvolley_height, orient = "h",ax=axes[12,1]).set_title("Female Beach Volleyball")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_biathlon_weight, orient = "h",ax=axes[13,0]).set_title("Male Biathlon")
sb.boxplot(x = "Height", y = "Medal", data = male_biathlon_height, orient = "h",ax=axes[13,1]).set_title("Male Biathlon")

sb.boxplot(x = "Weight", y = "Medal",data = female_biathlon_weight, orient = "h",ax=axes[14,0]).set_title("Female Biathlon")
sb.boxplot(x = "Height", y = "Medal", data = female_biathlon_height, orient = "h",ax=axes[14,1]).set_title("Female Biathlon")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_bobsleigh_weight, orient = "h",ax=axes[15,0]).set_title("Male Bobsleigh Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_bobsleigh_height, orient = "h",ax=axes[15,1]).set_title("Male Bobsleigh Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_bobsleigh_weight, orient = "h",ax=axes[16,0]).set_title("Female Bobsleigh Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_bobsleigh_height, orient = "h",ax=axes[16,1]).set_title("Female Bobsleigh Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_boxing_weight, orient = "h",ax=axes[17,0]).set_title("Male Boxers")
sb.boxplot(x = "Height", y = "Medal", data = male_boxing_height, orient = "h",ax=axes[17,1]).set_title("Male Boxers")

sb.boxplot(x = "Weight", y = "Medal",data = female_boxing_weight, orient = "h",ax=axes[18,0]).set_title("Female Boxers")
sb.boxplot(x = "Height", y = "Medal", data = female_boxing_height, orient = "h",ax=axes[18,1]).set_title("Female Boxers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_canoe_weight, orient = "h",ax=axes[19,0]).set_title("Male Canoers")
sb.boxplot(x = "Height", y = "Medal", data = male_canoe_height, orient = "h",ax=axes[19,1]).set_title("Male Canoers")

sb.boxplot(x = "Weight", y = "Medal",data = female_canoe_weight, orient = "h",ax=axes[20,0]).set_title("Female Canoers")
sb.boxplot(x = "Height", y = "Medal", data = female_canoe_height, orient = "h",ax=axes[20,1]).set_title("Female Canoers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_ccskiing_weight, orient = "h",ax=axes[21,0]).set_title("Male Cross-Country Skiiers")
sb.boxplot(x = "Height", y = "Medal", data = male_ccskiing_height, orient = "h",ax=axes[21,1]).set_title("Male Cross-Country Skiiers")

sb.boxplot(x = "Weight", y = "Medal",data = female_ccskiing_weight, orient = "h",ax=axes[22,0]).set_title("Female Cross-Country Skiiers")
sb.boxplot(x = "Height", y = "Medal", data = female_ccskiing_height, orient = "h",ax=axes[22,1]).set_title("Female Cross-Country Skiiers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_curling_weight, orient = "h",ax=axes[23,0]).set_title("Male Curlers")
sb.boxplot(x = "Height", y = "Medal", data = male_curling_height, orient = "h",ax=axes[23,1]).set_title("Male Curlers")

sb.boxplot(x = "Weight", y = "Medal",data = female_curling_weight, orient = "h",ax=axes[24,0]).set_title("Female Curlers")
sb.boxplot(x = "Height", y = "Medal", data = female_curling_height, orient = "h",ax=axes[24,1]).set_title("Female Curlers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_cycling_weight, orient = "h",ax=axes[25,0]).set_title("Male Cyclers")
sb.boxplot(x = "Height", y = "Medal", data = male_cycling_height, orient = "h",ax=axes[25,1]).set_title("Male Cyclers")

sb.boxplot(x = "Weight", y = "Medal",data = female_cycling_weight, orient = "h",ax=axes[26,0]).set_title("Female Cyclers")
sb.boxplot(x = "Height", y = "Medal", data = female_cycling_height, orient = "h",ax=axes[26,1]).set_title("Female Cyclers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_diving_weight, orient = "h",ax=axes[27,0]).set_title("Male Divers")
sb.boxplot(x = "Height", y = "Medal", data = male_diving_height, orient = "h",ax=axes[27,1]).set_title("Male Divers")

sb.boxplot(x = "Weight", y = "Medal",data = female_diving_weight, orient = "h",ax=axes[28,0]).set_title("Female Divers")
sb.boxplot(x = "Height", y = "Medal", data = female_diving_height, orient = "h",ax=axes[28,1]).set_title("Female Divers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_equestrianism_weight, orient = "h",ax=axes[29,0]).set_title("Male Equestrianism Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_equestrianism_height, orient = "h",ax=axes[29,1]).set_title("Male Equestrianism Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_equestrianism_weight, orient = "h",ax=axes[30,0]).set_title("Female Equestrianism Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_equestrianism_height, orient = "h",ax=axes[30,1]).set_title("Female Equestrianism Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_fencing_weight, orient = "h",ax=axes[31,0]).set_title("Male Fencers")
sb.boxplot(x = "Height", y = "Medal", data = male_fencing_height, orient = "h",ax=axes[31,1]).set_title("Male Fencers")

sb.boxplot(x = "Weight", y = "Medal",data = female_fencing_weight, orient = "h",ax=axes[32,0]).set_title("Female Fencers")
sb.boxplot(x = "Height", y = "Medal", data = female_fencing_height, orient = "h",ax=axes[32,1]).set_title("Female Fencers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_figureskating_weight, orient = "h",ax=axes[33,0]).set_title("Male Figure Skaters")
sb.boxplot(x = "Height", y = "Medal", data = male_figureskating_height, orient = "h",ax=axes[33,1]).set_title("Male Figure Skaters")

sb.boxplot(x = "Weight", y = "Medal",data = female_figureskating_weight, orient = "h",ax=axes[34,0]).set_title("Female Figure Skaters")
sb.boxplot(x = "Height", y = "Medal", data = female_figureskating_height, orient = "h",ax=axes[34,1]).set_title("Female Figure Skaters")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_football_weight, orient = "h",ax=axes[35,0]).set_title("Male Footballers")
sb.boxplot(x = "Height", y = "Medal", data = male_football_height, orient = "h",ax=axes[35,1]).set_title("Male Footballers")

sb.boxplot(x = "Weight", y = "Medal",data = female_football_weight, orient = "h",ax=axes[36,0]).set_title("Female Footballers")
sb.boxplot(x = "Height", y = "Medal", data = female_football_height, orient = "h",ax=axes[36,1]).set_title("Female Footballers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_fskiing_weight, orient = "h",ax=axes[37,0]).set_title("Male Freestyle Skiiers")
sb.boxplot(x = "Height", y = "Medal", data = male_fskiing_height, orient = "h",ax=axes[37,1]).set_title("Male Freestyle Skiiers")

sb.boxplot(x = "Weight", y = "Medal",data = female_fskiing_weight, orient = "h",ax=axes[38,0]).set_title("Female Freestyle Skiiers")
sb.boxplot(x = "Height", y = "Medal", data = female_fskiing_height, orient = "h",ax=axes[38,1]).set_title("Female Freestyle Skiiers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_golf_weight, orient = "h",ax=axes[39,0]).set_title("Male Golfers")
sb.boxplot(x = "Height", y = "Medal", data = male_golf_height, orient = "h",ax=axes[39,1]).set_title("Male Golfers")

sb.boxplot(x = "Weight", y = "Medal",data = female_golf_weight, orient = "h",ax=axes[40,0]).set_title("Female Golfers")
sb.boxplot(x = "Height", y = "Medal", data = female_golf_height, orient = "h",ax=axes[40,1]).set_title("Female Golfers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_gymnastics_weight, orient = "h",ax=axes[41,0]).set_title("Male Gymnastics Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_gymnastics_height, orient = "h",ax=axes[41,1]).set_title("Male Gymnastics Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_gymnastics_weight, orient = "h",ax=axes[42,0]).set_title("Female Gymnastics Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_gymnastics_height, orient = "h",ax=axes[42,1]).set_title("Female Gymnastics Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_handball_weight, orient = "h",ax=axes[43,0]).set_title("Male Handballers")
sb.boxplot(x = "Height", y = "Medal", data = male_handball_height, orient = "h",ax=axes[43,1]).set_title("Male Handballers")

sb.boxplot(x = "Weight", y = "Medal",data = female_handball_weight, orient = "h",ax=axes[44,0]).set_title("Female Handballers")
sb.boxplot(x = "Height", y = "Medal", data = female_handball_height, orient = "h",ax=axes[44,1]).set_title("Female Handballers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_hockey_weight, orient = "h",ax=axes[45,0]).set_title("Male Hockey Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_hockey_height, orient = "h",ax=axes[45,1]).set_title("Male Hockey Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_hockey_weight, orient = "h",ax=axes[46,0]).set_title("Female Hockey Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_hockey_height, orient = "h",ax=axes[46,1]).set_title("Female Hockey Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_icehockey_weight, orient = "h",ax=axes[47,0]).set_title("Male Ice Hockey Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_icehockey_height, orient = "h",ax=axes[47,1]).set_title("Male Ice Hockey Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_icehockey_weight, orient = "h",ax=axes[48,0]).set_title("Female Ice Hockey Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_icehockey_height, orient = "h",ax=axes[48,1]).set_title("Female Ice Hockey Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_judo_weight, orient = "h",ax=axes[49,0]).set_title("Male Judo Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_judo_height, orient = "h",ax=axes[49,1]).set_title("Male Judo Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_judo_weight, orient = "h",ax=axes[50,0]).set_title("Female Judo Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_judo_height, orient = "h",ax=axes[50,1]).set_title("Female Judo Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_luge_weight, orient = "h",ax=axes[51,0]).set_title("Male Luge Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_luge_height, orient = "h",ax=axes[51,1]).set_title("Male Luge Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_luge_weight, orient = "h",ax=axes[52,0]).set_title("Female Luge Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_luge_height, orient = "h",ax=axes[52,1]).set_title("Female Luge Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_pentathlon_weight, orient = "h",ax=axes[53,0]).set_title("Male Pentathlon Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_pentathlon_height, orient = "h",ax=axes[53,1]).set_title("Male Pentathlon Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_pentathlon_weight, orient = "h",ax=axes[54,0]).set_title("Female Pentathlon Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_pentathlon_height, orient = "h",ax=axes[54,1]).set_title("Female Pentathlon Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_nordic_weight, orient = "h",ax=axes[55,0]).set_title("Male Nordic Combined Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_nordic_height, orient = "h",ax=axes[55,1]).set_title("Male Nordic Combined Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = female_rgymnastics_weight, orient = "h",ax=axes[56,0]).set_title("Female Rhythym Gymnastics Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_rgymnastics_height, orient = "h",ax=axes[56,1]).set_title("Female Rhythym Gymnastics Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_rowing_weight, orient = "h",ax=axes[57,0]).set_title("Male Rowers")
sb.boxplot(x = "Height", y = "Medal", data = male_rowing_height, orient = "h",ax=axes[57,1]).set_title("Male Rowers")

sb.boxplot(x = "Weight", y = "Medal",data = female_rowing_weight, orient = "h",ax=axes[58,0]).set_title("Female Rowers")
sb.boxplot(x = "Height", y = "Medal", data = female_rowing_height, orient = "h",ax=axes[58,1]).set_title("Female Rowers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_rugby_weight, orient = "h",ax=axes[59,0]).set_title("Male Rugby Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_rugby_height, orient = "h",ax=axes[59,1]).set_title("Male Rugby Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_rugby7_weight, orient = "h",ax=axes[60,0]).set_title("Male Rugby 7 Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_rugby7_height, orient = "h",ax=axes[60,1]).set_title("Male Rugby 7 Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_rugby7_weight, orient = "h",ax=axes[61,0]).set_title("Female Rugby 7 Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_rugby7_height, orient = "h",ax=axes[61,1]).set_title("Female Rugby 7 Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_sailing_weight, orient = "h",ax=axes[62,0]).set_title("Male Sailors")
sb.boxplot(x = "Height", y = "Medal", data = male_sailing_height, orient = "h",ax=axes[62,1]).set_title("Male Sailors")

sb.boxplot(x = "Weight", y = "Medal",data = female_sailing_weight, orient = "h",ax=axes[63,0]).set_title("Female Sailors")
sb.boxplot(x = "Height", y = "Medal", data = female_sailing_height, orient = "h",ax=axes[63,1]).set_title("Female Sailors")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_shooting_weight, orient = "h",ax=axes[64,0]).set_title("Male Shooters")
sb.boxplot(x = "Height", y = "Medal", data = male_shooting_height, orient = "h",ax=axes[64,1]).set_title("Male Shooters")

sb.boxplot(x = "Weight", y = "Medal",data = female_shooting_weight, orient = "h",ax=axes[65,0]).set_title("Female Shooters")
sb.boxplot(x = "Height", y = "Medal", data = female_shooting_height, orient = "h",ax=axes[65,1]).set_title("Female Shooters")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_shortskating_weight, orient = "h",ax=axes[66,0]).set_title("Male Short Track Speed Skaters")
sb.boxplot(x = "Height", y = "Medal", data = male_shortskating_height, orient = "h",ax=axes[66,1]).set_title("Male Short Track Speed Skaters")

sb.boxplot(x = "Weight", y = "Medal",data = female_shortskating_weight, orient = "h",ax=axes[67,0]).set_title("Female Short Track Speed Skaters")
sb.boxplot(x = "Height", y = "Medal", data = female_shortskating_height, orient = "h",ax=axes[67,1]).set_title("Female Short Track Speed Skaters")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_skeleton_weight, orient = "h",ax=axes[68,0]).set_title("Male Skeleton Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_skeleton_height, orient = "h",ax=axes[68,1]).set_title("Male Skeleton Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_skeleton_weight, orient = "h",ax=axes[69,0]).set_title("Female Skeleton Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_skeleton_height, orient = "h",ax=axes[69,1]).set_title("Female Skeleton Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_skijump_weight, orient = "h",ax=axes[70,0]).set_title("Male Ski Jump Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_skijump_height, orient = "h",ax=axes[70,1]).set_title("Male Ski Jump Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_skijump_weight, orient = "h",ax=axes[71,0]).set_title("Female Ski Jump Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_skijump_height, orient = "h",ax=axes[71,1]).set_title("Female Ski Jump Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_snowboarding_weight, orient = "h",ax=axes[72,0]).set_title("Male Snowboarders")
sb.boxplot(x = "Height", y = "Medal", data = male_snowboarding_height, orient = "h",ax=axes[72,1]).set_title("Male Snowboarders")

sb.boxplot(x = "Weight", y = "Medal",data = female_snowboarding_weight, orient = "h",ax=axes[73,0]).set_title("Female Snowboarders")
sb.boxplot(x = "Height", y = "Medal", data = female_snowboarding_height, orient = "h",ax=axes[73,1]).set_title("Female Snowboarders")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = female_softball_weight, orient = "h",ax=axes[74,0]).set_title("Female Softballers")
sb.boxplot(x = "Height", y = "Medal", data = female_softball_height, orient = "h",ax=axes[74,1]).set_title("Female Softballers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_speedskating_weight, orient = "h",ax=axes[75,0]).set_title("Male Speedskaters")
sb.boxplot(x = "Height", y = "Medal", data = male_speedskating_height, orient = "h",ax=axes[75,1]).set_title("Male Speedskaters")

sb.boxplot(x = "Weight", y = "Medal",data = female_speedskating_weight, orient = "h",ax=axes[76,0]).set_title("Female Speedskaters")
sb.boxplot(x = "Height", y = "Medal", data = female_speedskating_height, orient = "h",ax=axes[76,1]).set_title("Female Speedskaters")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_swimming_weight, orient = "h",ax=axes[77,0]).set_title("Male Swimmers")
sb.boxplot(x = "Height", y = "Medal", data = male_swimming_height, orient = "h",ax=axes[77,1]).set_title("Male Swimmers")

sb.boxplot(x = "Weight", y = "Medal",data = female_swimming_weight, orient = "h",ax=axes[78,0]).set_title("Female Swimmers")
sb.boxplot(x = "Height", y = "Medal", data = female_swimming_height, orient = "h",ax=axes[78,1]).set_title("Female Swimmers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = female_syncswimming_weight, orient = "h",ax=axes[79,0]).set_title("Female Synchronised Swimmers")
sb.boxplot(x = "Height", y = "Medal", data = female_syncswimming_height, orient = "h",ax=axes[79,1]).set_title("Female Synchronised Swimmers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_tabletennis_weight, orient = "h",ax=axes[80,0]).set_title("Male Table Tennis Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_tabletennis_height, orient = "h",ax=axes[80,1]).set_title("Male Table Tennis Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_tabletennis_weight, orient = "h",ax=axes[81,0]).set_title("Female Table Tennis Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_tabletennis_height, orient = "h",ax=axes[81,1]).set_title("Female Table Tennis Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_taekwondo_weight, orient = "h",ax=axes[82,0]).set_title("Male Taekwondo Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_taekwondo_height, orient = "h",ax=axes[82,1]).set_title("Male Taekwondo Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_taekwondo_weight, orient = "h",ax=axes[83,0]).set_title("Female Taekwondo Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_taekwondo_height, orient = "h",ax=axes[83,1]).set_title("Female Taekwondo Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_tennis_weight, orient = "h",ax=axes[84,0]).set_title("Male Tennis Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_tennis_height, orient = "h",ax=axes[84,1]).set_title("Male Tennis Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_tennis_weight, orient = "h",ax=axes[85,0]).set_title("Female Tennis Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_tennis_height, orient = "h",ax=axes[85,1]).set_title("Female Tennis Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_trampolining_weight, orient = "h",ax=axes[86,0]).set_title("Male Trampolining Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_trampolining_height, orient = "h",ax=axes[86,1]).set_title("Male Trampolining Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_trampolining_weight, orient = "h",ax=axes[87,0]).set_title("Female Trampolining Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_trampolining_height, orient = "h",ax=axes[87,1]).set_title("Female Trampolining Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_triathlon_weight, orient = "h",ax=axes[88,0]).set_title("Male Triathlon Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_triathlon_height, orient = "h",ax=axes[88,1]).set_title("Male Triathlon Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_triathlon_weight, orient = "h",ax=axes[89,0]).set_title("Female Triathlon Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_triathlon_height, orient = "h",ax=axes[89,1]).set_title("Female Triathlon Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_tugofwar_weight, orient = "h",ax=axes[90,0]).set_title("Male Tug-of-war Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_tugofwar_height, orient = "h",ax=axes[90,1]).set_title("Male Tug-of-war Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_volleyball_weight, orient = "h",ax=axes[91,0]).set_title("Male Volleyballers")
sb.boxplot(x = "Height", y = "Medal", data = male_volleyball_height, orient = "h",ax=axes[91,1]).set_title("Male Volleyballers")

sb.boxplot(x = "Weight", y = "Medal",data = female_volleyball_weight, orient = "h",ax=axes[92,0]).set_title("Female Volleyballers")
sb.boxplot(x = "Height", y = "Medal", data = female_volleyball_height, orient = "h",ax=axes[92,1]).set_title("Female Volleyballers")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_waterpolo_weight, orient = "h",ax=axes[93,0]).set_title("Male Water Polo Athletes")
sb.boxplot(x = "Height", y = "Medal", data = male_waterpolo_height, orient = "h",ax=axes[93,1]).set_title("Male Water Polo Athletes")

sb.boxplot(x = "Weight", y = "Medal",data = female_waterpolo_weight, orient = "h",ax=axes[94,0]).set_title("Female Water Polo Athletes")
sb.boxplot(x = "Height", y = "Medal", data = female_waterpolo_height, orient = "h",ax=axes[94,1]).set_title("Female Water Polo Athletes")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_weightlifting_weight, orient = "h",ax=axes[95,0]).set_title("Male Weightlifters")
sb.boxplot(x = "Height", y = "Medal", data = male_weightlifting_height, orient = "h",ax=axes[95,1]).set_title("Male Weightlifters")

sb.boxplot(x = "Weight", y = "Medal",data = female_weightlifting_weight, orient = "h",ax=axes[96,0]).set_title("Female Weightlifters")
sb.boxplot(x = "Height", y = "Medal", data = female_weightlifting_height, orient = "h",ax=axes[96,1]).set_title("Female Weightlifters")
##############################################################################################################################
sb.boxplot(x = "Weight", y = "Medal",data = male_wrestling_weight, orient = "h",ax=axes[97,0]).set_title("Male Wrestlers")
sb.boxplot(x = "Height", y = "Medal", data = male_wrestling_height, orient = "h",ax=axes[97,1]).set_title("Male Wrestlers")

sb.boxplot(x = "Weight", y = "Medal",data = female_wrestling_weight, orient = "h",ax=axes[98,0]).set_title("Female Wrestlers")
sb.boxplot(x = "Height", y = "Medal", data = female_wrestling_height, orient = "h",ax=axes[98,1]).set_title("Female Wrestlers")
##############################################################################################################################
